# %%
import utils as utl
import numpy as np
import matplotlib.pyplot as plt
import analyse_utils as atl

# %% [markdown]
# databases available from https://www.homesmartmesh.com/docs/networks/ultrawideband/#database

# %%
dbfileName = "./test_db/2021.07.17/tag_four_ping 2021.07.17 17-26-01.json"
#ranges = utl.load_json("./test_db/2021.07.17/tag_four_twr 2021.07.17 16-39-56.json")
diag_list = utl.load_json(dbfileName)
atl.set_data_list(diag_list)
print(f"lodaded {len(diag_list)} entries from '{dbfileName}'")
# Out:
# lodaded 588 entries from './test_db/2021.07.17/tag_four_ping 2021.07.17 17-26-01.json'

# %%
fig, axs = plt.subplots(4, 3, sharex=True, sharey=True)

atl.plot_axis_param("fpAmp1",0,1,axs[0,0])
atl.plot_axis_param("fpAmp2",0,1,axs[0,1])
atl.plot_axis_param("fpAmp3",0,1,axs[0,2])

atl.plot_axis_param("fpAmp1",0,2,axs[1,0])
atl.plot_axis_param("fpAmp2",0,2,axs[1,1])
atl.plot_axis_param("fpAmp3",0,2,axs[1,2])

atl.plot_axis_param("fpAmp1",0,3,axs[2,0])
atl.plot_axis_param("fpAmp2",0,3,axs[2,1])
atl.plot_axis_param("fpAmp3",0,3,axs[2,2])

atl.plot_axis_param("fpAmp1",0,4,axs[3,0])
atl.plot_axis_param("fpAmp2",0,4,axs[3,1])
atl.plot_axis_param("fpAmp3",0,4,axs[3,2])

fig.set_size_inches(18,10)

# %%
fig, axs = plt.subplots(4, 1, sharex=True, sharey=True)

atl.plot_axis_param("stdNoise",0,1,axs[0])
atl.plot_axis_param("stdNoise",0,2,axs[1])
atl.plot_axis_param("stdNoise",0,3,axs[2])
atl.plot_axis_param("stdNoise",0,4,axs[3])

fig.set_size_inches(9,10)

# %%
fig, axs = plt.subplots(4, 1, sharex=True, sharey=True)

atl.plot_axis_param("maxNoise",0,1,axs[0])
atl.plot_axis_param("maxNoise",0,2,axs[1])
atl.plot_axis_param("maxNoise",0,3,axs[2])
atl.plot_axis_param("maxNoise",0,4,axs[3])

fig.set_size_inches(9,10)

# %%
fig, axs = plt.subplots(4, 1, sharex=True, sharey=True)

atl.plot_axis_param("maxGrowthCIR",0,1,axs[0])
atl.plot_axis_param("maxGrowthCIR",0,2,axs[1])
atl.plot_axis_param("maxGrowthCIR",0,3,axs[2])
atl.plot_axis_param("maxGrowthCIR",0,4,axs[3])

fig.set_size_inches(9,10)

# %%
fig, axs = plt.subplots(4, 1, sharex=True, sharey=True)

atl.plot_axis_param("rxPreamCount",0,1,axs[0])
atl.plot_axis_param("rxPreamCount",0,2,axs[1])
atl.plot_axis_param("rxPreamCount",0,3,axs[2])
atl.plot_axis_param("rxPreamCount",0,4,axs[3])

fig.set_size_inches(9,10)
